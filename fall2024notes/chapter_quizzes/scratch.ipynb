# %%
# Scratch Work

# %%
import turtle

def shape(length, reps, angle):
    for i in range(reps):
        turtle.forward(length)
        turtle.right(angle)

# turtle.reset()
# shape(100, 5, 360 // 5)

def square(length):
    for i in range(4):
        turtle.forward(length)
        turtle.right(90)

# turtle.reset()
# for i in range(9):
#     square(100)
#     turtle.right(360/9)

def flower(length, shape_func):
    for i in range(12):
        shape_func(length)
        turtle.right(30)

# turtle.reset()
# flower(100, square)

def dd(x):
    if x == 0:
        return x
    elif x < 0:
        return x - 1
    else:
        return x + 1

# print(dd(2) + dd(-2))

def word(x, y):
    if x == y:
        print('fish')
    else:
        if x < y:
            print('bird')
        else:
            print('shoe')

# word('a', 'A')
# word('bug', 'chop')

def f(n):
    if n < 5:
        print(n)
    else:
        print(n)
        f(n-1)

# f(8)

def hello():
    print('hello')

# x = hello()
# print(x)

def combine(a, b):
    return a + b

x = combine(3, 4)
# print(x)

def middle(x):
    print(f'x = {x}')
    return x - 1
    print(f'x = {x}')

# m = middle(5)
# print(f'm = {m}')

def parity(n):
    return n % 2 == 0

def parity1(n):
    if n % 2 == 0:
        return True
    else:
        return False

def parity2(n):
    if n % 2 == 0:
        return False
    else:
        return True

def parity3(n):
    if n % 2 == 1:
        return True
    else:
        return False

def parity4(n):
    if n % 2 == 1:
        return False
    else:
        return True

def parity5(n):
    if n % 2 == 0:
        return True
    if n % 2 == 1:
        return False

def parity6(n):
    if n % 2 == 0:
        return True
    elif n % 2 == 1:
        return False

def parity7(n):
    if n % 2 == 0:
        return True
    return False

def test_parity(n):
    print(f'{n} is even: {parity(n)}')
    print(f'{n} is even: {parity1(n)}')
    print(f'{n} is even: {parity2(n)}')
    print(f'{n} is even: {parity3(n)}')
    print(f'{n} is even: {parity4(n)}')
    print(f'{n} is even: {parity5(n)}')
    print(f'{n} is even: {parity6(n)}')
    print(f'{n} is even: {parity7(n)}')

# test_parity(1)
# test_parity(2)

def f1(s, t):
    if len(s) < len(t):
        return False
    else:
        return True
    
def f2(s, t):
    return len(s) >= len(t)


def g(n):
    if n == 0:
        return 2
    else:
        return n + g(n - 1)

# print(g(3))

# for n in range(5):
#     print(f'g({n}) = {g(n)}')

def fib_mod(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return 1 + fib_mod(n - 1) + fib_mod(n - 2)

# for n in range(6):
#     print(f'fib_mod({n}) = {fib_mod(n)}')

# for letter in "tree":
#     print(letter, end='!')

def has_x1(word):
    for letter in word:
        if letter == 'x' or letter == 'X':
            return True
    
    return False

def has_x2(word):
    return 'x' in word or 'X' in word

def has_x3(word):
    for letter in word:
        if letter in 'xX':
            return True
    return False

def has_x_test(s):
    print(f'has_x1("{s}") = {has_x1(s)}')
    print(f'has_x2("{s}") = {has_x2(s)}')
    print(f'has_x3("{s}") = {has_x3(s)}')

# has_x_test('tree')
# has_x_test('xray')

def count_vowels(s):
    """Returns the number of vowels in s.
    """
    count = 0
    for letter in s:
        if letter in 'aeiouAEIOU':
            count += 1
    return count

def count_vowels_buggy(s):
    """Buggy: returns the number of vowels in s.
    """
    count = 0
    for vowel in 'aeiouAEIOU':
        if vowel in s:
            count += 1
    return count

def test_count_vowels(s):
    print(f'count_vowels("{s}") = {count_vowels(s)}')
    print(f'count_vowels_buggy("{s}") = {count_vowels_buggy(s)}')

# test_count_vowels('tree')
# test_count_vowels('xray')

# s = 'candy'
# print(s[-len(s)] + s[-1])

# s = 'candy' * 20
# print(len(s[70:80]))

# names = ['Alice', 'Bob', 'Charlie']
# rest = names[1:]
# rest[-1] = 'David'
# print(names[-1])

# lst = [2, 3, 4, 5]
# print(', '.join(str(x) for x in lst))

def arrange(lst):
    lst.sort()

a = [4, 6, 1]
arrange(a)
print(a)
# Out:
# [1, 4, 6]
